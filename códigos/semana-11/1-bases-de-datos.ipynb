# %% [markdown]
# # **Seminario de métodos computacionales para lenguas amerindias**
# ### Roberto Zariquiey Biondi, rzariquiey@pucp.edu.pe
# ### Javier Vera Zúñiga, jveraz@pucp.edu.pe

# %% [markdown]
# ## Datos de [Wals](https://github.com/cldf-datasets/wals/tree/master/cldf), [Glottolog](https://glottolog.org/meta/downloads), [diccionarios](https://realpython.com/python-dicts/) y [pandas](https://pandas.pydata.org/) (también [ver](https://pandas.pydata.org/docs/user_guide/index.html))

# %%
## importamos la librería
import pandas as pd

# %%
## descomente en el desafío

##from google.colab import files
##uploaded = files.upload()

# %% [markdown]
# ## Glottolog

# %%
## https://glottolog.org/meta/downloads
languages_glotto = pd.read_csv('languages_and_dialects_geo.csv')

# %%
languages_glotto
# Out:
#       glottocode        name isocodes     level  macroarea  latitude  \
# 0       3adt1234  3Ad-Tekles      NaN   dialect     Africa       NaN
# 1       aala1237      Aalawa      NaN   dialect  Papunesia       NaN
# 2       aant1238  Aantantara      NaN   dialect  Papunesia       NaN
# 3       aari1239        Aari      aiw  language     Africa   5.95034
# 4       aari1240      Aariya      aay  language    Eurasia       NaN
# ...          ...         ...      ...       ...        ...       ...
# 21647   zuwa1238     Zuwadza      NaN   dialect  Papunesia       NaN
# 21648   zwal1238       Zwall      NaN   dialect     Africa       NaN
# 21649   zyph1238       Zyphe      zyp  language    Eurasia  22.52400
# 21650   zyud1238     Zyuzdin      NaN   dialect    Eurasia       NaN
# 21651   huaa1249        ǂHua      NaN   dialect     Africa       NaN
#
#        longitude
# 0            NaN
# 1            NaN
# 2            NaN
# 3        36.5721
# 4            NaN
# ...          ...
# 21647        NaN
# 21648        NaN
# 21649    93.2640
# 21650        NaN
# 21651        NaN
#
# [21652 rows x 7 columns]

# %%
## reducimos las columnas

languages_glotto = languages_glotto[['glottocode','name','isocodes','macroarea','latitude','longitude']]

# %%
# ahora, filtramos las filas que tienen datos faltantes

languages_glotto = languages_glotto.dropna()

# %%
languages_glotto
# Out:
#       glottocode             name isocodes      macroarea  latitude  longitude
# 3       aari1239             Aari      aiw         Africa   5.95034   36.57210
# 5       aasa1238            Aasax      aas         Africa  -4.00679   36.86480
# 11      abad1241            Abadi      kbt      Papunesia  -9.03389  146.99200
# 13      abag1245            Abaga      abg      Papunesia  -6.12028  145.66500
# 15      abai1240      Abai Sungai      abf      Papunesia   5.55394  118.30600
# ...          ...              ...      ...            ...       ...        ...
# 21634   zuma1239           Zumaya      zuy         Africa  10.55798   14.44451
# 21636   zumb1240           Zumbun      jmb         Africa  10.82700    9.96830
# 21641   zuni1245             Zuni      zun  North America  35.00560 -108.78200
# 21642   zuoj1238  Zuojiang Zhuang      zzj        Eurasia  22.40000  106.90000
# 21649   zyph1238            Zyphe      zyp        Eurasia  22.52400   93.26400
#
# [7809 rows x 6 columns]

# %% [markdown]
# ### Pregunta 1: ¿Cuántas lenguas hay por macroarea?

# %%
## identificamos las macroareas

## definimos una lista vacía
macroareas = []

## recorremos la lista de macroareas
for M in list(languages_glotto['macroarea']):
    ## si no está, la agregamos
    if M not in macroareas:
        macroareas += [M]

# %%
## verificamos

macroareas
# Out:
# ['Africa',
#  'Papunesia',
#  'Eurasia',
#  'South America',
#  'North America',
#  'Australia']

# %%
## diccionario de macroareas

macroareas_dict = {}

## recorremos las macroareas
for M in macroareas:
    ## filtramos por lenguas de una macroarea
    languages_macroarea = languages_glotto[languages_glotto['macroarea'] == M]
    ## agregamos
    macroareas_dict[M] = languages_macroarea

# %%
## número de lenguas: tamaño de los dataframes

for M in macroareas_dict.keys():
    ## mostramos el largo de los dataframes
    print(M, len(macroareas_dict[M]))
# Out:
# Africa 2243
# Papunesia 2150
# Eurasia 1817
# South America 547
# North America 686
# Australia 366

# %% [markdown]
# ### Pregunta 2: ¿Cuántas familias lingüísticas hay por macroarea?

# %%
## https://glottolog.org/meta/downloads
languoid = pd.read_csv('languoid.csv')

# %%
languoid
# Out:
#              id family_id parent_id                 name  bookkeeping  \
# 0      3adt1234  afro1255  nort3292           3Ad-Tekles        False
# 1      aala1237  aust1307  ramo1244               Aalawa        False
# 2      aant1238  nucl1709  nort2920           Aantantara        False
# 3      aari1238  sout2845  ahkk1235           Aari-Gayil        False
# 4      aari1239  sout2845  aari1238                 Aari        False
# ...         ...       ...       ...                  ...          ...
# 26280  zuti1239  tupi1275  guaj1255  Guajajára of Zutiua        False
# 26281  zuwa1238  koia1260  omie1241              Zuwadza        False
# 26282  zwal1238  atla1278  shal1242                Zwall        False
# 26283  zyph1238  sino1245  nucl1757                Zyphe        False
# 26284  zyud1238  ural1272  komi1269              Zyuzdin        False
#
#           level  latitude  longitude iso639P3code  description  \
# 0       dialect       NaN        NaN          NaN          NaN
# 1       dialect       NaN        NaN          NaN          NaN
# 2       dialect       NaN        NaN          NaN          NaN
# 3        family       NaN        NaN          aiz          NaN
# 4      language   5.95034    36.5721          aiw          NaN
# ...         ...       ...        ...          ...          ...
# 26280   dialect       NaN        NaN          NaN          NaN
# 26281   dialect       NaN        NaN          NaN          NaN
# 26282   dialect       NaN        NaN          NaN          NaN
# 26283  language  22.52400    93.2640          zyp          NaN
# 26284   dialect       NaN        NaN          NaN          NaN
#
#        markup_description  child_family_count  child_language_count  \
# 0                     NaN                   0                     0
# 1                     NaN                   0                     0
# 2                     NaN                   0                     0
# 3                     NaN                   0                     2
# 4                     NaN                   0                     0
# ...                   ...                 ...                   ...
# 26280                 NaN                   0                     0
# 26281                 NaN                   0                     0
# 26282                 NaN                   0                     0
# 26283                 NaN                   0                     0
# 26284                 NaN                   0                     0
#
#        child_dialect_count country_ids
# 0                        0         NaN
# 1                        0         NaN
# 2                        0         NaN
# 3                        0         NaN
# 4                        0          ET
# ...                    ...         ...
# 26280                    0         NaN
# 26281                    0         NaN
# 26282                    0         NaN
# 26283                    2       IN MM
# 26284                    0         NaN
#
# [26285 rows x 15 columns]

# %%
languoid = languoid[['id', 'family_id']]

# %%
# ahora, filtramos las filas que tienen datos faltantes

languoid = languoid.dropna()

# %%
languoid
# Out:
#              id family_id
# 0      3adt1234  afro1255
# 1      aala1237  aust1307
# 2      aant1238  nucl1709
# 3      aari1238  sout2845
# 4      aari1239  sout2845
# ...         ...       ...
# 26280  zuti1239  tupi1275
# 26281  zuwa1238  koia1260
# 26282  zwal1238  atla1278
# 26283  zyph1238  sino1245
# 26284  zyud1238  ural1272
#
# [25858 rows x 2 columns]

# %%
## diccionario lengua:familia

## lista lenguas
L = list(languoid['id'])

## lista familias
F = list(languoid['family_id'])

## diccionario vacío
language_family = {}

## recorremos las lenguas: usamos los índices
for i in range(len(list(languoid['id']))):
    
    ## lengua
    lengua = L[i]
    
    ## familia
    familia = F[i]
    
    ## creamos el par lengua:familia
    language_family[lengua] = familia

# %%
## el diccionario macroareas_dict tiene como keys las macroareas y como values los dataframes
## creamos una versión con las lenguas

macroareas_dict_lenguas = {}

## recorremos las macroareas
for macroarea in macroareas_dict.keys():
    
    ## dataframe
    lenguas = macroareas_dict[macroarea]
    
    ## lenguas
    lenguas = list(lenguas['glottocode'])
    
    ## guardamos
    macroareas_dict_lenguas[macroarea] = lenguas

# %%
## comprobamos! número de lenguas: tamaño de las listas

for M in macroareas_dict_lenguas.keys():
    ## mostramos el largo de las listas
    print(M, len(macroareas_dict_lenguas[M]))
# Out:
# Africa 2243
# Papunesia 2150
# Eurasia 1817
# South America 547
# North America 686
# Australia 366

# %% [markdown]
# ### Desafío grupal. Responda la pregunta 2.
# ¿Qué podríamos concluir de estos cálculos? ¿Qué otras preguntas cuantitativas sobre familias lingüísticas podrían hacerse?
#
# **Recomendación!** Defina un diccionario en donde intercambie las lenguas de **macroareas_dict_lenguas** por las familias del diccionario **language_family**. Tengan la precaución de saltarse las lenguas que no aparezcan en el diccionario **language_family**.

# %% [markdown]
# ### Pregunta 3: ¿Cuántas lenguas están anotadas en Wals por macroarea?

# %%
## lenguas de wals https://github.com/cldf-datasets/wals/tree/master/cldf
languages_wals = pd.read_csv('languages_wals.csv')

# %%
languages_wals
# Out:
#        ID                  Name      Macroarea   Latitude   Longitude  \
# 0     aab         Arapesh (Abu)      Papunesia  -3.450000  142.950000
# 1     aar                  Aari         Africa   6.000000   36.583333
# 2     aba                  Abau      Papunesia  -4.000000  141.250000
# 3     abb      Arabic (Chadian)         Africa  13.833333   20.833333
# 4     abd                Abidji         Africa   5.666667   -4.583333
# ...   ...                   ...            ...        ...         ...
# 2657  zte  Zapotec (Texmelucan)  North America  16.500000  -97.166667
# 2658  zul                  Zulu         Africa -30.000000   30.000000
# 2659  zun                  Zuni  North America  35.083333 -108.833333
# 2660  zya    Zapotec (Yatzachi)  North America  17.200000  -96.200000
# 2661  zzo    Zapotec (Zoogocho)  North America  17.250000  -96.250000
#
#      Glottocode ISO639P3code        Family    Subfamily           Genus  \
# 0      abua1245          aah    Torricelli          NaN  Kombio-Arapesh
# 1      aari1239          aiw  Afro-Asiatic       Omotic    South Omotic
# 2      abau1245          aau         Sepik          NaN            Abau
# 3      chad1249          shu  Afro-Asiatic          NaN         Semitic
# 4      abid1235          abi   Niger-Congo          Kwa          Agneby
# ...         ...          ...           ...          ...             ...
# 2657   texm1235          zpz  Oto-Manguean          NaN       Zapotecan
# 2658   zulu1248          zul   Niger-Congo  Benue-Congo           Bantu
# 2659   zuni1245          zun           NaN          NaN             NaN
# 2660   yatz1235          zav  Oto-Manguean          NaN       Zapotecan
# 2661   zoog1238          zpq  Oto-Manguean          NaN       Zapotecan
#
#      GenusIcon ISO_codes  Samples_100  Samples_200 Country_ID  \
# 0      c51CC56       aah        False        False         PG
# 1      c708033       aiw        False        False         ET
# 2      c807433       aau        False        False         PG
# 3      cB3CC51       shu        False        False         TD
# 4      c523380       abi        False        False         CI
# ...        ...       ...          ...          ...        ...
# 2657   c5162CC       zpz        False        False         MX
# 2658   cC3CC51       zul         True         True         ZA
# 2659   c805C33       zun        False        False         US
# 2660   c5162CC       zav        False        False         MX
# 2661   c5162CC       zpq        False        False         MX
#
#                                                  Source
# 0                                          Nekitel-1985
# 1                                         Hayward-1990a
# 2                                           Bailey-1975
# 3                                         Abu-Absi-1995
# 4                                                   NaN
# ...                                                 ...
# 2657                                                NaN
# 2658  Canonici-1989 Canonici-1995 Cope-1982 Dahl-198...
# 2659  Bunzel-1933-1938 Bybee-et-al-1994 Cook-1975 Mi...
# 2660                                        Butler-1980
# 2661           Long-C-and-Cruz-M-1999 Sonnenschein-2005
#
# [2662 rows x 16 columns]

# %%
## lista de lenguas de wals
lista_lenguas_wals = list(languages_wals['Glottocode'])

## creamos un diccionario con listas
macroareas_dict_lenguas_wals = {M:[] for M in macroareas_dict_lenguas.keys()}

## recorremos las macroareas de macroareas_dict_lenguas
for M in macroareas_dict_lenguas.keys():
    
    ## lenguas de una macroarea
    lenguas_macroarea = macroareas_dict_lenguas[M]
    
    ## revisamos cuáles de estas lenguas están en wals
    for lengua in lenguas_macroarea:
        ## si está en la lista de lenguas de wals
        if lengua in lista_lenguas_wals:
            ## guardamos
            macroareas_dict_lenguas_wals[M] += [lengua]

# %%
## miramos! 

for M in macroareas_dict_lenguas.keys():
    ## mostramos el largo de las listas
    print(M, len(macroareas_dict_lenguas[M]), len(macroareas_dict_lenguas_wals[M]))
# Out:
# Africa 2243 567
# Papunesia 2150 546
# Eurasia 1817 543
# South America 547 240
# North America 686 346
# Australia 366 162

# %% [markdown]
# ### Preguntas pendientes:
# - ¿Cuántas familias están anotadas en Wals para cada macroarea?
# - ¿Cúantos rasgos están anotados en Wals para todas las lenguas? ¿En promedio, cuántos rasgos están anotados para una lengua cualquiera? ¿Y por macroárea?
# - Considere las lenguas de Sudamérica. Asuma que una lengua está anotada en Wals si tiene al menos un rasgo. ¿Qué porcentaje de lenguas de cada familia lingüística está anotada en Wals?
# - ¿Qué porcentaje del total de rasgos de Wals están anotados para las lenguas de Sudamérica?
