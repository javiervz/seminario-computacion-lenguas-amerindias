# %% [markdown]
# # **Seminario de métodos computacionales para lenguas amerindias**
# ### Roberto Zariquiey Biondi, rzariquiey@pucp.edu.pe
# ### Javier Vera Zúñiga, jveraz@pucp.edu.pe

# %% [markdown]
# ## Datos de [Wals](https://github.com/cldf-datasets/wals/tree/master/cldf), mapas y [pandas](https://pandas.pydata.org/)

# %%
## importamos la librería
import pandas as pd

# %%
## descomente en el desafío

##from google.colab import files
##uploaded = files.upload()

# %% [markdown]
# ### ¿Cómo construimos un mapa con las lenguas de Sudamérica que aparecen en Wals?

# %%
## lenguas de wals https://github.com/cldf-datasets/wals/tree/master/cldf
languages_wals = pd.read_csv('languages_wals.csv')

# %%
languages_wals
# Out:
#        ID                  Name      Macroarea   Latitude   Longitude  \
# 0     aab         Arapesh (Abu)      Papunesia  -3.450000  142.950000
# 1     aar                  Aari         Africa   6.000000   36.583333
# 2     aba                  Abau      Papunesia  -4.000000  141.250000
# 3     abb      Arabic (Chadian)         Africa  13.833333   20.833333
# 4     abd                Abidji         Africa   5.666667   -4.583333
# ...   ...                   ...            ...        ...         ...
# 2657  zte  Zapotec (Texmelucan)  North America  16.500000  -97.166667
# 2658  zul                  Zulu         Africa -30.000000   30.000000
# 2659  zun                  Zuni  North America  35.083333 -108.833333
# 2660  zya    Zapotec (Yatzachi)  North America  17.200000  -96.200000
# 2661  zzo    Zapotec (Zoogocho)  North America  17.250000  -96.250000
#
#      Glottocode ISO639P3code        Family    Subfamily           Genus  \
# 0      abua1245          aah    Torricelli          NaN  Kombio-Arapesh
# 1      aari1239          aiw  Afro-Asiatic       Omotic    South Omotic
# 2      abau1245          aau         Sepik          NaN            Abau
# 3      chad1249          shu  Afro-Asiatic          NaN         Semitic
# 4      abid1235          abi   Niger-Congo          Kwa          Agneby
# ...         ...          ...           ...          ...             ...
# 2657   texm1235          zpz  Oto-Manguean          NaN       Zapotecan
# 2658   zulu1248          zul   Niger-Congo  Benue-Congo           Bantu
# 2659   zuni1245          zun           NaN          NaN             NaN
# 2660   yatz1235          zav  Oto-Manguean          NaN       Zapotecan
# 2661   zoog1238          zpq  Oto-Manguean          NaN       Zapotecan
#
#      GenusIcon ISO_codes  Samples_100  Samples_200 Country_ID  \
# 0      c51CC56       aah        False        False         PG
# 1      c708033       aiw        False        False         ET
# 2      c807433       aau        False        False         PG
# 3      cB3CC51       shu        False        False         TD
# 4      c523380       abi        False        False         CI
# ...        ...       ...          ...          ...        ...
# 2657   c5162CC       zpz        False        False         MX
# 2658   cC3CC51       zul         True         True         ZA
# 2659   c805C33       zun        False        False         US
# 2660   c5162CC       zav        False        False         MX
# 2661   c5162CC       zpq        False        False         MX
#
#                                                  Source
# 0                                          Nekitel-1985
# 1                                         Hayward-1990a
# 2                                           Bailey-1975
# 3                                         Abu-Absi-1995
# 4                                                   NaN
# ...                                                 ...
# 2657                                                NaN
# 2658  Canonici-1989 Canonici-1995 Cope-1982 Dahl-198...
# 2659  Bunzel-1933-1938 Bybee-et-al-1994 Cook-1975 Mi...
# 2660                                        Butler-1980
# 2661           Long-C-and-Cruz-M-1999 Sonnenschein-2005
#
# [2662 rows x 16 columns]

# %%
## filtramos por lenguas de Sudamérica
languages_wals = languages_wals[languages_wals['Macroarea'] == 'South America']

# %%
languages_wals
# Out:
#        ID       Name      Macroarea   Latitude  Longitude Glottocode  \
# 7     abi     Abipón  South America -29.000000 -61.000000   abip1241
# 17    acg    Achagua  South America   4.416667 -72.250000   acha1250
# 18    ach       Aché  South America -25.250000 -55.166667   ache1246
# 24    acu     Achuar  South America  -2.666670 -76.000000   achu1248
# 28    adk     Andoke  South America  -0.666667 -72.000000   ando1256
# ...   ...        ...            ...        ...        ...        ...
# 2612  yrc   Yuracare  South America -16.583333 -65.250000   yura1255
# 2613  yrm  Yurimangí  South America   3.833333 -77.000000   yuru1243
# 2614  yrr     Yaruro  South America   7.000000 -68.000000   pume1238
# 2615  yrt     Yuruti  South America   1.000000 -70.416667   yuru1263
# 2650  zpr     Zaparo  South America  -2.000000 -76.333333   zapa1253
#
#      ISO639P3code      Family Subfamily            Genus GenusIcon ISO_codes  \
# 7             axb  Guaicuruan       NaN           Abipon   c805E33       axb
# 17            aca    Arawakan       NaN  Japura-Colombia   c9A51CC       aca
# 18            guq      Tupian       NaN   Maweti-Guarani   cCC6351       guq
# 24            acu    Jivaroan       NaN         Jivaroan   c80334E       acu
# 28            ano         NaN       NaN              NaN   cC1CC51       ano
# ...           ...         ...       ...              ...       ...       ...
# 2612          yuz         NaN       NaN              NaN   c806333       yuz
# 2613          NaN         NaN       NaN              NaN   cCC9F51       NaN
# 2614          yae         NaN       NaN              NaN   c806E33       yae
# 2615          yui    Tucanoan       NaN         Tucanoan   c6FCC51       yui
# 2650          zro    Zaparoan       NaN         Zaparoan   cCC9951       zro
#
#       Samples_100  Samples_200 Country_ID  \
# 7           False         True         AR
# 17          False        False         CO
# 18          False        False         PY
# 24          False        False         PE
# 28          False        False         CO
# ...           ...          ...        ...
# 2612        False        False         BO
# 2613        False        False         CO
# 2614        False        False         VR
# 2615        False        False         CO
# 2650        False        False      EC PE
#
#                                                  Source
# 7        Bybee-et-al-1994 Dobrizhoffer-1902 Najlis-1966
# 17    Aikhenvald-2007b Huber-and-Reed-1992 Melendez-...
# 18                                          Susnik-1974
# 24                         Fast-and-Fast-1981 Wise-1978
# 28             Aikhenvald-and-Dixon-1999 Landaburu-1979
# ...                                                 ...
# 2612                                        Suarez-1973
# 2613                            Adelaar-2004 Rivet-1942
# 2614                                Mosonyi-et-al-2000a
# 2615                                Huber-and-Reed-1992
# 2650                                         Peeke-1962
#
# [258 rows x 16 columns]

# %%
## extraemos tres listas: lenguas, latitud, longitud

## lenguas
lenguas = list(languages_wals['Name'])

## latitud
latitud = list(languages_wals['Latitude'])

## longitud
longitud = list(languages_wals['Longitude'])

# %%
lenguas[:5], latitud[:5], longitud[:5]
# Out:
# (['Abipón', 'Achagua', 'Aché', 'Achuar', 'Andoke'],
#  [-29.0, 4.41666666667, -25.25, -2.66667, -0.666666666667],
#  [-61.0, -72.25, -55.1666666667, -76.0, -72.0])

# %%
## construyamos un diccionario lengua:[latitud, longitud]
diccionario_loc = {}

## recorremos los índices
for i in range(len(lenguas)):
    ## lengua
    lengua = lenguas[i]
    
    ## latitud
    lat = latitud[i]
    
    ## longitud
    lon = longitud[i]
    
    ## guardamos
    diccionario_loc[lengua] = [lat, lon]

# %%
diccionario_loc
# Out:
# {'Abipón': [-29.0, -61.0],
#  'Achagua': [4.41666666667, -72.25],
#  'Aché': [-25.25, -55.1666666667],
#  'Achuar': [-2.66667, -76.0],
#  'Andoke': [-0.666666666667, -72.0],
#  'Aguaruna': [-5.0, -78.0],
#  'Aikaná': [-12.6666666667, -60.6666666667],
#  'Akawaio': [6.0, -59.5],
#  'Allentiac': [-31.0, -68.0],
#  'Amahuaca': [-10.5, -72.5],
#  'Amarakaeri': [-12.5, -70.5],
#  'Amuesha': [-10.5, -75.4166666667],
#  'Araona': [-12.3333333333, -67.75],
#  'Apinayé': [-5.5, -48.0],
#  'Apalaí': [0.0, -54.0],
#  'Apurinã': [-9.0, -67.0],
#  'Lokono': [5.5, -55.1666666667],
#  'Arabela': [-2.0, -75.1666666667],
#  'Asuriní': [-3.5, -49.5],
#  'Atacameño': [-23.0, -69.0],
#  'Awa Pit': [1.5, -78.25],
#  'Aymara (Central)': [-17.0, -69.0],
#  'Ayomán': [11.0, -69.0],
#  'Ayoreo': [-20.25, -59.25],
#  'Baré': [1.0, -67.0],
#  'Xiriana': [2.66666666666667, -62.5],
#  'Baure': [-13.0833333333, -64.1666666667],
#  'Berbice Dutch Creole': [5.33333333333, -58.0],
#  'Bakairí': [-14.0, -55.0],
#  'Banawá': [-7.0, -65.0],
#  'Waimaha': [0.333333333333, -70.25],
#  'Baniva': [5.26, -67.56],
#  'Baniwa': [2.66666666667, -66.8333333333],
#  'Bora': [-2.16666666667, -72.3333333333],
#  'Bororo': [-16.0, -57.0],
#  'Barasano': [-0.166666666667, -70.6666666667],
#  'Betoi': [7.16666666667, -71.25],
#  'Cacua': [1.08333333333, -70.0],
#  'Camsá': [1.16666666667, -77.0],
#  'Candoshi': [-4.16666666667, -77.0],
#  'Capanahua': [-7.0, -74.0],
#  'Carib': [5.5, -56.0],
#  'Cashibo': [-8.5, -75.5],
#  'Catio': [7.16666666667, -76.3333333333],
#  'Cavineña': [-13.3333333333, -66.5],
#  'Campa (Axininca)': [-12.0, -74.0],
#  'Cayapa': [0.666666666667, -79.0],
#  'Chácobo': [-12.1666666667, -66.75],
#  "Carib (De'kwana)": [5.5, -65.0],
#  'Nivacle': [-23.5, -60.5],
#  'Chayahuita': [-5.5, -77.0],
#  'Cholón': [-8.0, -77.5],
#  'Chimila': [10.0, -74.0],
#  'Canela': [-7.0, -45.0],
#  'Canamarí': [-6.5, -68.5],
#  'Cocama': [-5.0, -74.5],
#  'Cofán': [0.166666666667, -77.1666666667],
#  'Cogui': [11.0, -73.8333333333],
#  'Campa Pajonal Asheninca': [-10.6666666667, -74.25],
#  'Chipaya': [-18.75, -67.8333333333],
#  'Chiquitano': [-17.5, -60.0],
#  'Chiriguano': [-23.6666666667, -64.3333333333],
#  'Carijona': [1.0, -73.0],
#  'Carapana': [0.833333333333, -70.75],
#  'Chorote': [-22.5, -62.5],
#  'Cashinahua': [-10.5, -71.8333333333],
#  'Cubeo': [1.33333333333, -70.5],
#  'Cuica': [9.0, -70.5],
#  'Cuiba': [6.5, -70.0],
#  'Culina': [-6.0, -70.5],
#  'Curripaco': [2.5, -68.5],
#  'Cayuvava': [-13.5, -65.5],
#  'Damana': [11.0, -73.5],
#  'Dâw': [-0.25, -67.0833333333],
#  'Dení': [-6.0, -67.0],
#  'Desano': [0.833333333333, -69.8333333333],
#  'Emberá (Northern)': [6.83333333333, -77.1666666667],
#  'Embera Chami': [5.0, -76.0],
#  'Émérillon': [3.16666666667, -52.4166666667],
#  'Epena Pedee': [3.0, -77.0],
#  'Ese Ejja': [-11.0, -66.0],
#  'Esmeraldeño': [0.333333333333, -79.8333333333],
#  'Fulniô': [-8.0, -37.5],
#  'Gavião': [-10.6666666667, -62.0],
#  'Guianese French Creole': [5.0, -53.0],
#  'Guahibo': [5.0, -69.0],
#  'Guajajara': [-5.0, -46.0],
#  'Gününa Küne': [-41.0, -67.0],
#  'Guambiano': [2.5, -76.6666666667],
#  'Guana': [-22.0, -58.0],
#  'Guanano': [0.833333333333, -69.5],
#  'Goajiro': [12.0, -72.0],
#  'Guató': [-17.0, -58.0],
#  'Guaraní': [-26.0, -56.0],
#  'Guaque': [1.0, -72.0833333333],
#  'Guayabero': [2.83333333333, -72.0],
#  'Hianacoto': [0.833333333333, -71.0],
#  'Hixkaryana': [-1.0, -59.0],
#  'Huambisa': [-4.0, -78.0],
#  'Huitoto (Minica)': [-0.333333333333, -74.0],
#  'Huitoto (Muinane)': [-2.41666666667, -71.0],
#  'Hup': [0.166666666667, -69.25],
#  'Huitoto (Murui)': [-1.0, -73.5],
#  'Inga': [1.0, -77.0],
#  'Ignaciano': [-15.1666666667, -65.4166666667],
#  'Ika': [10.6666666667, -73.75],
#  'Iquito': [-3.25, -74.0],
#  'Iranxe': [-13.0, -58.0],
#  'Itonama': [-12.8333333333, -64.3333333333],
#  'Jaqaru': [-13.0, -76.0],
#  'Jabutí': [-12.25, -62.25],
#  'Jebero': [-5.41666666667, -76.5],
#  'Jivaro': [-2.5, -78.0],
#  'Jamamadi': [-7.5, -67.0],
#  'Japreria': [10.5, -73.0],
#  'Juruna': [-5.0, -54.5],
#  'Júma': [-7.5, -64.0],
#  'Karajá': [-10.0, -50.3333333333],
#  'Jarawara': [-7.5, -65.5],
#  'Karó (Arára)': [-10.3333333333, -62.0],
#  'Kaiwá': [-23.0, -55.0],
#  'Karipuna (Panoan)': [-10.0, -65.0],
#  'Kadiwéu': [-20.0, -57.0],
#  'Koreguaje': [1.0, -75.5],
#  'Kuikúro': [-12.4166666667, -53.0833333333],
#  'Kamaiurá': [-12.0833333333, -52.5833333333],
#  'Karitiâna': [-9.5, -64.0],
#  'Kaingang': [-26.0, -52.0],
#  'Kanoê': [-13.25, -61.0],
#  'Krenak': [-15.5, -41.0],
#  'Krahô': [-8.0, -48.0],
#  'Kipea': [-10.0, -37.0],
#  'Kuna': [8.0, -77.3333333333],
#  'Kwaza': [-12.5833333333, -60.6666666667],
#  'Kayapó': [-9.0, -52.0],
#  'Kayabí': [-11.0, -55.5],
#  'Leko': [-15.0, -67.9166666667],
#  'Lengua': [-22.5, -59.0],
#  'Lengua de Señas Argentina': [-34.0, -63.0],
#  'Língua de Sinais Brasileira': [-15.0, -48.0],
#  'Lule': [-28.0, -64.0],
#  'Macushi': [4.0, -60.0],
#  'Mapudungun': [-38.0, -72.0],
#  'Maxakalí': [-18.0, -40.0],
#  'Maca': [-25.0, -57.5],
#  'Mochica': [-7.5, -79.3333333333],
#  'Macaguán': [6.5, -71.3333333333],
#  'Machiguenga': [-12.0, -72.6666666667],
#  'Macuna': [-0.333333333333, -70.1666666667],
#  'Mocoví': [-28.0, -60.5],
#  'Mekens': [-12.5, -61.5],
#  'Máku': [0.416666666667, -69.8333333333],
#  'Mosetén': [-14.75, -67.8333333333],
#  'Movima': [-13.8333333333, -65.6666666667],
#  'Maipure': [5.5, -67.5],
#  'Mapoyo': [6.0, -67.0],
#  'Muisca': [5.0, -74.0],
#  'Barí': [9.0, -73.0],
#  'Matis': [-4.41666666667, -70.25],
#  'Muinane': [-1.0, -72.5],
#  'Mundurukú': [-7.0, -58.0],
#  'Matsés': [-5.41666666667, -73.25],
#  'Nadëb': [-1.0, -66.5],
#  'Ndyuka': [4.5, -54.5],
#  'Nambikuára (Southern)': [-14.0, -59.5],
#  'Nomatsiguenga': [-11.6666666667, -74.5],
#  'Nukak': [2.5, -71.5],
#  'Ocaina': [-2.75, -71.75],
#  'Omagua': [-4.0, -73.5],
#  'Orejón': [-2.83333333333, -72.5],
#  'Páez': [2.66666666667, -76.0],
#  'Paumarí': [-6.0, -64.0],
#  'Pemon': [5.33333333333, -62.0],
#  'Pilagá': [-25.0, -60.0],
#  'Piaroa': [5.0, -67.0],
#  'Piro': [-11.0, -73.5],
#  'Playero': [7.0, -71.0],
#  'Palikur': [3.0, -51.0],
#  'Panare': [6.5, -66.0],
#  'Panará': [-10.0, -55.0],
#  'Piapoco': [4.0, -69.5],
#  'Paresi': [-14.0, -57.5],
#  'Pirahã': [-7.0, -62.0],
#  'Piratapuyo': [0.333333333333, -69.5],
#  'Puinave': [4.0, -68.0],
#  'Puquina': [-16.5, -68.5],
#  'Quechua (Ancash)': [-8.5, -77.5],
#  'Qawasqar': [-49.0, -75.0],
#  'Quechua (Ayacucho)': [-14.0, -74.0],
#  'Quechua (Bolivian)': [-20.0, -66.0],
#  'Quechua (Cajamarca)': [-7.0, -78.5],
#  'Quechua (Cochabamba)': [-17.5, -66.0],
#  'Quechua (Cuzco)': [-14.5, -71.0],
#  'Quechua (Ecuadorean)': [-1.0, -79.0],
#  'Quechua (Huallaga)': [-9.5, -75.5],
#  'Quechua (Imbabura)': [0.333333333333, -78.0],
#  'Quechua (Tarma)': [-11.4166666667, -75.75],
#  'Resígaro': [-2.41666666667, -71.5],
#  'Retuarã': [-0.5, -70.6666666667],
#  'Rikbaktsa': [-11.8333333333, -57.5],
#  'Sáliba (in Colombia)': [6.0, -70.0],
#  'Secoya': [-0.333333333333, -76.0],
#  'Selknam': [-53.0, -70.0],
#  'Sharanahua': [-11.0, -70.0],
#  'Shiriana': [3.5, -62.8333333333],
#  'Shipibo-Konibo': [-7.5, -75.0],
#  'Siona': [0.333333333333, -76.25],
#  'Sanuma': [4.5, -64.6666666667],
#  'Sranan': [5.83333333333, -55.3333333333],
#  'Siriano': [0.75, -70.1666666667],
#  'Saramaccan': [4.5, -55.5],
#  'Sirionó': [-15.5833333333, -64.0],
#  'Tacana': [-13.5, -68.0],
#  'Tariana': [1.0, -69.1666666667],
#  'Tehuelche': [-48.0, -68.0],
#  'Ticuna': [-4.0, -70.5],
#  'Tiriyo': [3.25, -55.75],
#  'Tunebo': [6.75, -72.25],
#  'Toba': [-26.5, -59.0],
#  'Tapieté': [-19.75, -61.6666666667],
#  'Terêna': [-20.0, -56.0],
#  'Trumai': [-11.9166666667, -53.5833333333],
#  'Tsafiki': [-1.0, -79.3333333333],
#  'Taushiro': [-3.25, -75.5],
#  'Tatuyo': [0.416666666667, -70.5],
#  'Tucano': [0.5, -69.1666666667],
#  'Tupi': [-6.0, -36.0],
#  'Tuyuca': [0.5, -70.0833333333],
#  'Umaua': [1.0, -72.0],
#  'Urubú-Kaapor': [-2.33333333333, -46.5],
#  'Urarina': [-4.5, -75.5],
#  'Uru': [-16.75, -69.0],
#  'Urubú Sign Language': [-2.33333333333, -46.0],
#  'Wai Wai': [1.0, -59.0],
#  'Waorani': [-1.0, -76.5],
#  "Wari'": [-11.3333333333, -65.0],
#  'Waunana': [4.0, -77.0],
#  'Wayampi': [1.0, -52.0],
#  'Wichí': [-22.5, -62.5833333333],
#  'Wapishana': [2.66666666667, -60.0],
#  'Warao': [9.33333333333, -61.6666666667],
#  'Warekena': [1.5, -67.5],
#  'Waurá': [-13.0, -53.0],
#  'Wayana': [3.25, -54.1666666667],
#  'Xavánte': [-15.0, -52.5],
#  'Xerénte': [-10.0, -48.1666666667],
#  'Xokleng': [-24.5, -50.0],
#  'Yagua': [-3.5, -72.0],
#  'Yahgan': [-55.0, -68.0],
#  'Yaminahua': [-8.0, -73.0],
#  'Yucuna': [-0.75, -71.0],
#  'Yukpa': [10.1666666667, -72.75],
#  'Yanomámi': [2.33333333333, -63.0],
#  'Yuracare': [-16.5833333333, -65.25],
#  'Yurimangí': [3.83333333333, -77.0],
#  'Yaruro': [7.0, -68.0],
#  'Yuruti': [1.0, -70.4166666667],
#  'Zaparo': [-2.0, -76.3333333333]}

# %%
## instalar librería (esto funciona en colab)
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (0.9.0)
# Requirement already satisfied: fiona>=1.8 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.3.3)
# WARNING: You are using pip version 21.3.1; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\jxver\anaconda3\envs\geo_env\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (3.2.0)
# Requirement already satisfied: shapely>=1.6 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: attrs>=17 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: certifi in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: click>=4.0 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (1.12.0)
# Requirement already satisfied: munch in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (59.8.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jxver\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (2.8.2)

# %%
## librería para hacer mapas
import geopandas

# %%
## accedemos al mundo
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 6 columns]

# %%
## filtramos para el territorio de Sudamérica
world = world[world['continent']=='South America']

# %%
## librería famosa de gráficos en Python
import matplotlib.pyplot as plt

## conviene definir fig
fig, ax = plt.subplots(dpi=800)

## título
plt.title('Lenguas anotadas en Wals',fontsize=5)

## colores
world.plot(ax=ax, color='honeydew', edgecolor='k',linewidth=0.2)

#for language in location.keys():
#    if language in languages_conflict:
#        ax.annotate(max(probs[language].round(2)), weight='demi', color='k', xy=(location[language][1],location[language][0]), fontsize=2.5, alpha=0.85)

ax.plot(longitud,latitud, marker='o',color='orange',markersize=2.5,markeredgewidth=0.25,markeredgecolor='k',alpha=0.75,linewidth=0,fillstyle='full',clip_on=True)

#plt.legend(loc='best',fontsize=3)
ax.set_yticks([])
ax.set_xticks([])
plt.savefig('map_SA.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %%
## otra versión: etiquetas

## conviene definir fig
fig, ax = plt.subplots(dpi=800)

## título
plt.title('Lenguas anotadas en Wals',fontsize=5)

## colores
world.plot(ax=ax, color='honeydew', edgecolor='k',linewidth=0.2)

## usamos annotate
for language in diccionario_loc.keys():
    ax.annotate(language, color='k', xy=(diccionario_loc[language][1], diccionario_loc[language][0]), fontsize=1.5, alpha=0.85)

ax.plot(longitud,latitud, marker='o',color='orange',markersize=2.5,markeredgewidth=0.1,markeredgecolor='k',alpha=0.75,linewidth=0,fillstyle='full',clip_on=True)

#plt.legend(loc='best',fontsize=3)
ax.set_yticks([])
ax.set_xticks([])
plt.savefig('map_SA_nombres.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %%
## mostremos algunas familias

## extraemos la lista de familias
familias = list(languages_wals['Family'])

# %%
## construyamos un diccionario lengua:familia
lengua_familia = {}

## recorremos los índices
for i in range(len(lenguas)):
    ## lengua
    lengua = lenguas[i]
    
    ## familia
    familia = familias[i]
    
    ## guardamos
    lengua_familia[lengua] = familia

# %%
lengua_familia
# Out:
# {'Abipón': 'Guaicuruan',
#  'Achagua': 'Arawakan',
#  'Aché': 'Tupian',
#  'Achuar': 'Jivaroan',
#  'Andoke': nan,
#  'Aguaruna': 'Jivaroan',
#  'Aikaná': nan,
#  'Akawaio': 'Cariban',
#  'Allentiac': 'Huarpe',
#  'Amahuaca': 'Pano-Tacanan',
#  'Amarakaeri': 'Harakmbet',
#  'Amuesha': 'Arawakan',
#  'Araona': 'Pano-Tacanan',
#  'Apinayé': 'Macro-Ge',
#  'Apalaí': 'Cariban',
#  'Apurinã': 'Arawakan',
#  'Lokono': 'Arawakan',
#  'Arabela': 'Zaparoan',
#  'Asuriní': 'Tupian',
#  'Atacameño': 'Kunza',
#  'Awa Pit': 'Barbacoan',
#  'Aymara (Central)': 'Aymaran',
#  'Ayomán': 'Jirajaran',
#  'Ayoreo': 'Zamucoan',
#  'Baré': 'Arawakan',
#  'Xiriana': 'Arawakan',
#  'Baure': 'Arawakan',
#  'Berbice Dutch Creole': 'other',
#  'Bakairí': 'Cariban',
#  'Banawá': 'Arauan',
#  'Waimaha': 'Tucanoan',
#  'Baniva': 'Arawakan',
#  'Baniwa': 'Arawakan',
#  'Bora': 'Boran',
#  'Bororo': 'Bororoan',
#  'Barasano': 'Tucanoan',
#  'Betoi': nan,
#  'Cacua': 'Cacua-Nukak',
#  'Camsá': nan,
#  'Candoshi': nan,
#  'Capanahua': 'Pano-Tacanan',
#  'Carib': 'Cariban',
#  'Cashibo': 'Pano-Tacanan',
#  'Catio': 'Choco',
#  'Cavineña': 'Pano-Tacanan',
#  'Campa (Axininca)': 'Arawakan',
#  'Cayapa': 'Barbacoan',
#  'Chácobo': 'Pano-Tacanan',
#  "Carib (De'kwana)": 'Cariban',
#  'Nivacle': 'Matacoan',
#  'Chayahuita': 'Cahuapanan',
#  'Cholón': 'Hobitu-Cholon',
#  'Chimila': 'Chibchan',
#  'Canela': 'Macro-Ge',
#  'Canamarí': 'Katukinan',
#  'Cocama': 'Tupian',
#  'Cofán': nan,
#  'Cogui': 'Chibchan',
#  'Campa Pajonal Asheninca': 'Arawakan',
#  'Chipaya': 'Uru-Chipaya',
#  'Chiquitano': nan,
#  'Chiriguano': 'Tupian',
#  'Carijona': 'Cariban',
#  'Carapana': 'Tucanoan',
#  'Chorote': 'Matacoan',
#  'Cashinahua': 'Pano-Tacanan',
#  'Cubeo': 'Tucanoan',
#  'Cuica': 'Timote-Cuica',
#  'Cuiba': 'Guahiban',
#  'Culina': 'Arauan',
#  'Curripaco': 'Arawakan',
#  'Cayuvava': nan,
#  'Damana': 'Chibchan',
#  'Dâw': 'Nadahup',
#  'Dení': 'Arauan',
#  'Desano': 'Tucanoan',
#  'Emberá (Northern)': 'Choco',
#  'Embera Chami': 'Choco',
#  'Émérillon': 'Tupian',
#  'Epena Pedee': 'Choco',
#  'Ese Ejja': 'Pano-Tacanan',
#  'Esmeraldeño': 'Tacame',
#  'Fulniô': nan,
#  'Gavião': 'Tupian',
#  'Guianese French Creole': 'other',
#  'Guahibo': 'Guahiban',
#  'Guajajara': 'Tupian',
#  'Gününa Küne': 'Chonan',
#  'Guambiano': 'Barbacoan',
#  'Guana': 'Mascoian',
#  'Guanano': 'Tucanoan',
#  'Goajiro': 'Arawakan',
#  'Guató': nan,
#  'Guaraní': 'Tupian',
#  'Guaque': 'Cariban',
#  'Guayabero': 'Guahiban',
#  'Hianacoto': 'Cariban',
#  'Hixkaryana': 'Cariban',
#  'Huambisa': 'Jivaroan',
#  'Huitoto (Minica)': 'Witotoan',
#  'Huitoto (Muinane)': 'Witotoan',
#  'Hup': 'Nadahup',
#  'Huitoto (Murui)': 'Witotoan',
#  'Inga': 'Quechuan',
#  'Ignaciano': 'Arawakan',
#  'Ika': 'Chibchan',
#  'Iquito': 'Zaparoan',
#  'Iranxe': nan,
#  'Itonama': nan,
#  'Jaqaru': 'Aymaran',
#  'Jabutí': 'Macro-Ge',
#  'Jebero': 'Cahuapanan',
#  'Jivaro': 'Jivaroan',
#  'Jamamadi': 'Arauan',
#  'Japreria': 'Cariban',
#  'Juruna': 'Tupian',
#  'Júma': 'Tupian',
#  'Karajá': 'Macro-Ge',
#  'Jarawara': 'Arauan',
#  'Karó (Arára)': 'Tupian',
#  'Kaiwá': 'Tupian',
#  'Karipuna (Panoan)': 'Pano-Tacanan',
#  'Kadiwéu': 'Guaicuruan',
#  'Koreguaje': 'Tucanoan',
#  'Kuikúro': 'Cariban',
#  'Kamaiurá': 'Tupian',
#  'Karitiâna': 'Tupian',
#  'Kaingang': 'Macro-Ge',
#  'Kanoê': 'Kapixana',
#  'Krenak': 'Macro-Ge',
#  'Krahô': 'Macro-Ge',
#  'Kipea': 'Kariri',
#  'Kuna': 'Chibchan',
#  'Kwaza': nan,
#  'Kayapó': 'Macro-Ge',
#  'Kayabí': 'Tupian',
#  'Leko': nan,
#  'Lengua': 'Mascoian',
#  'Lengua de Señas Argentina': 'other',
#  'Língua de Sinais Brasileira': 'other',
#  'Lule': nan,
#  'Macushi': 'Cariban',
#  'Mapudungun': 'Araucanian',
#  'Maxakalí': 'Macro-Ge',
#  'Maca': 'Matacoan',
#  'Mochica': nan,
#  'Macaguán': 'Guahiban',
#  'Machiguenga': 'Arawakan',
#  'Macuna': 'Tucanoan',
#  'Mocoví': 'Guaicuruan',
#  'Mekens': 'Tupian',
#  'Máku': nan,
#  'Mosetén': 'Mosetenan',
#  'Movima': nan,
#  'Maipure': 'Arawakan',
#  'Mapoyo': 'Cariban',
#  'Muisca': 'Chibchan',
#  'Barí': 'Chibchan',
#  'Matis': 'Pano-Tacanan',
#  'Muinane': 'Boran',
#  'Mundurukú': 'Tupian',
#  'Matsés': 'Pano-Tacanan',
#  'Nadëb': 'Nadahup',
#  'Ndyuka': 'other',
#  'Nambikuára (Southern)': 'Nambikuaran',
#  'Nomatsiguenga': 'Arawakan',
#  'Nukak': 'Cacua-Nukak',
#  'Ocaina': 'Witotoan',
#  'Omagua': 'Tupian',
#  'Orejón': 'Tucanoan',
#  'Páez': 'Páezan',
#  'Paumarí': 'Arauan',
#  'Pemon': 'Cariban',
#  'Pilagá': 'Guaicuruan',
#  'Piaroa': 'Sáliban',
#  'Piro': 'Arawakan',
#  'Playero': 'Guahiban',
#  'Palikur': 'Arawakan',
#  'Panare': 'Cariban',
#  'Panará': 'Macro-Ge',
#  'Piapoco': 'Arawakan',
#  'Paresi': 'Arawakan',
#  'Pirahã': 'Mura',
#  'Piratapuyo': 'Tucanoan',
#  'Puinave': nan,
#  'Puquina': nan,
#  'Quechua (Ancash)': 'Quechuan',
#  'Qawasqar': 'Alacalufan',
#  'Quechua (Ayacucho)': 'Quechuan',
#  'Quechua (Bolivian)': 'Quechuan',
#  'Quechua (Cajamarca)': 'Quechuan',
#  'Quechua (Cochabamba)': 'Quechuan',
#  'Quechua (Cuzco)': 'Quechuan',
#  'Quechua (Ecuadorean)': 'Quechuan',
#  'Quechua (Huallaga)': 'Quechuan',
#  'Quechua (Imbabura)': 'Quechuan',
#  'Quechua (Tarma)': 'Quechuan',
#  'Resígaro': 'Arawakan',
#  'Retuarã': 'Tucanoan',
#  'Rikbaktsa': 'Macro-Ge',
#  'Sáliba (in Colombia)': 'Sáliban',
#  'Secoya': 'Tucanoan',
#  'Selknam': 'Chonan',
#  'Sharanahua': 'Pano-Tacanan',
#  'Shiriana': 'Yanomam',
#  'Shipibo-Konibo': 'Pano-Tacanan',
#  'Siona': 'Tucanoan',
#  'Sanuma': 'Yanomam',
#  'Sranan': 'other',
#  'Siriano': 'Tucanoan',
#  'Saramaccan': 'other',
#  'Sirionó': 'Tupian',
#  'Tacana': 'Pano-Tacanan',
#  'Tariana': 'Arawakan',
#  'Tehuelche': 'Chonan',
#  'Ticuna': nan,
#  'Tiriyo': 'Cariban',
#  'Tunebo': 'Chibchan',
#  'Toba': 'Guaicuruan',
#  'Tapieté': 'Tupian',
#  'Terêna': 'Arawakan',
#  'Trumai': nan,
#  'Tsafiki': 'Barbacoan',
#  'Taushiro': nan,
#  'Tatuyo': 'Tucanoan',
#  'Tucano': 'Tucanoan',
#  'Tupi': 'Tupian',
#  'Tuyuca': 'Tucanoan',
#  'Umaua': 'Cariban',
#  'Urubú-Kaapor': 'Tupian',
#  'Urarina': nan,
#  'Uru': 'Uru-Chipaya',
#  'Urubú Sign Language': 'other',
#  'Wai Wai': 'Cariban',
#  'Waorani': nan,
#  "Wari'": 'Chapacura-Wanham',
#  'Waunana': 'Choco',
#  'Wayampi': 'Tupian',
#  'Wichí': 'Matacoan',
#  'Wapishana': 'Arawakan',
#  'Warao': nan,
#  'Warekena': 'Arawakan',
#  'Waurá': 'Arawakan',
#  'Wayana': 'Cariban',
#  'Xavánte': 'Macro-Ge',
#  'Xerénte': 'Macro-Ge',
#  'Xokleng': 'Macro-Ge',
#  'Yagua': 'Peba-Yaguan',
#  'Yahgan': 'Yámana',
#  'Yaminahua': 'Pano-Tacanan',
#  'Yucuna': 'Arawakan',
#  'Yukpa': 'Cariban',
#  'Yanomámi': 'Yanomam',
#  'Yuracare': nan,
#  'Yurimangí': nan,
#  'Yaruro': nan,
#  'Yuruti': 'Tucanoan',
#  'Zaparo': 'Zaparoan'}

# %%
## otra versión: familias

## conviene definir fig
fig, ax = plt.subplots(dpi=800)

## título
plt.title('Lenguas anotadas en Wals',fontsize=5)

## colores
world.plot(ax=ax, color='honeydew', edgecolor='k',linewidth=0.2)

## usamos annotate
for language in diccionario_loc.keys():
    ## familia
    familia = lengua_familia[language]
    ## anotamos algunas familias
    if familia in ['Pano-Tacanan']:
        ax.annotate(familia, color='k', xy=(diccionario_loc[language][1], diccionario_loc[language][0]), fontsize=2., alpha=0.85)

ax.plot(longitud,latitud, marker='o',color='orange',markersize=2.5,markeredgewidth=0.1,markeredgecolor='k',alpha=0.5,linewidth=0,fillstyle='full',clip_on=True)

#plt.legend(loc='best',fontsize=3)
ax.set_yticks([])
ax.set_xticks([])
plt.savefig('map_SA_familias.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %%
## otra versión: familias 2

## conviene definir fig
fig, ax = plt.subplots(dpi=800)

## título
plt.title('Lenguas anotadas en Wals',fontsize=5)

## colores
world.plot(ax=ax, color='honeydew', edgecolor='k',linewidth=0.2)

## usamos colores para las familias
## lon, lat para Pano-Tacanan
lon_PT = []
lat_PT = []

## índices lenguas Pano-Tacanan
indices_PT = []

## recorremos las lenguas
for i in range(len(lenguas)):
    ## condición Pano-Tacanan
    if lengua_familia[lenguas[i]] == 'Pano-Tacanan':
        ## guardamos
        indices_PT += [i]
        
## dividimos los datos de latitud/longitud en dos
latitud_PT = []
longitud_PT = []

latitud_non_PT = []
longitud_non_PT = []

## recorremos los índices
for i in range(len(lenguas)):
    ## casos
    if i in indices_PT:
        ## loc PT
        latitud_PT += [latitud[i]]
        longitud_PT += [longitud[i]]
    else:
        ## loc non PT
        latitud_non_PT += [latitud[i]]
        longitud_non_PT += [longitud[i]]
        
ax.plot(longitud_PT, latitud_PT, marker='o',color='orange',markersize=2.5,markeredgewidth=0.1,markeredgecolor='k',alpha=0.75,linewidth=0,fillstyle='full',clip_on=True, label='Pano-Tacanan')
ax.plot(longitud_non_PT, latitud_non_PT, marker='o',color='blue',markersize=2.5,markeredgewidth=0.1,markeredgecolor='k',alpha=0.75,linewidth=0,fillstyle='full',clip_on=True, label='otras familias')

plt.legend(loc='best',fontsize=3)
ax.set_yticks([])
ax.set_xticks([])
plt.savefig('map_SA_familias_colors.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()
