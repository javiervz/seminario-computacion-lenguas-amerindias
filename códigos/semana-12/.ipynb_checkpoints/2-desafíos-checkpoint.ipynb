# %% [markdown]
# # **Seminario de métodos computacionales para lenguas amerindias**
# ### Roberto Zariquiey Biondi, rzariquiey@pucp.edu.pe
# ### Javier Vera Zúñiga, jveraz@pucp.edu.pe

# %% [markdown]
# ## Datos de [Ethnologue](https://www.ethnologue.com/)
# Exploremos los datos de la tabla siguiente.

# %%
## Descomente las siguientes dos líneas y cargue el archivo en colab

#from google.colab import files
#uploaded = files.upload()

# %%
## importamos la librería mágica
import pandas as pd

## leemos como si fuera un archivo csv, con separación por tabs (algo muy típico)
population = pd.read_csv('hh24.tab',sep='\t')

# %%
population
# Out:
#      Agglomerated Endangerment  \
# 0               Not Endangered
# 1                 10 (Extinct)
# 2                          NaN
# 3                 10 (Extinct)
# 4                          NaN
# ...                        ...
# 8813            Not Endangered
# 8814            Not Endangered
# 8815            Not Endangered
# 8816                       NaN
# 8817            Not Endangered
#
#                        Agglomerated Endangerment Source  \
# 0     Glottolog [Thu Jun  17 11:26:38 2021] Seychell...
# 1     Glottolog [Sun Apr  5 23:26:38 2020] Borgu (NO...
# 2                                                   NaN
# 3     Glottolog [Fri Jan 05 17:27:48 2018] Adhari (N...
# 4                                                   NaN
# ...                                                 ...
# 8813  E24 [Mon Mar 15 20:30:07 2021] Zhuang, Youjian...
# 8814  E24 [Mon Mar 15 20:30:07 2021] Zhuang, Yongnan...
# 8815  E24 [Mon Mar 15 20:30:07 2021] Chin, Zyphe (zy...
# ...

# %%
## columnas

population.columns
# Out:
# Index(['Agglomerated Endangerment', 'Agglomerated Endangerment Source',
#        'Also spoken in', 'Alternate Names', 'Autonym', 'Classification',
#        'Classification-HH', 'Comment', 'Coordinates', 'Coordinates Source',
#        'Country', 'Dialects', 'E20 Endangerment', 'E21 Endangerment',
#        'E22 Endangerment', 'E23 Endangerment', 'E24 Endangerment',
#        'ElCat Endangerment', 'GLD', 'GLD-Names', 'ISO 639-3',
#        'Language Development', 'Language Maps', 'Language Resources',
#        'Language Status', 'Language Use', 'Location', 'Other Comments',
#        'Population', 'Population Numeric', 'Population_Old', 'Superseded',
#        'Timespan', 'Typology', 'UNESCO Endangerment', 'Writing', 'code+name',
#        'macro_area', 'name', 'total_population'],
#       dtype='object')

# %% [markdown]
# El desafío es proponer preguntas acerca de los datos:
#
# - ¿Qué cruces podrían hacerse entre **glottolog** y esta base de datos?
# - ¿Qué podría decirse acerca de familias lingüísticas y número de hablantes?
# - ¿Qué ocurre con la información de **vitalidad**?
# - ¿Cómo implementaría estas preguntas en **Python**?
