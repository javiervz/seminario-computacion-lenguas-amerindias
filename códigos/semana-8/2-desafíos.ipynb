# %% [markdown]
# # **Seminario de métodos computacionales para lenguas amerindias**
# ### Roberto Zariquiey Biondi, rzariquiey@pucp.edu.pe
# ### Javier Vera Zúñiga, jveraz@pucp.edu.pe

# %% [markdown]
# # Desafío 2

# %% [markdown]
# ## mini desafío 1
# En este mini desafío, usted y su equipo deben construir un diccionario de terminaciones para la lista **lista_numero_1_9.** Los keys deben corresponder a los elementos de esta lista. Si el string termina en vocal, el value debe ser 'vocal'; si termina en consonante, el value debe ser 'consonante'.

# %%
## lista de números del 1 al 9

lista_numeros_1_9 = ['huk', 'iskay', 'kimsa', 'tawa', 'pichqa', 'suqta', 'qanchis', 'pusaq', 'isqun']

# %%
## diccionario inicialmente vacío

terminaciones = {}

# %% [markdown]
# ## mini desafío 2
# En este mini desafío, usted y su equipo deben construir un diccionario en que las keys sean 'vocal' y 'consonante'; los values corresponden a listas que contienen los números de **lista_numero_1_9** cuyas terminaciones respectivas son 'vocal' y 'consonante'.

# %%
## diccionario semi-vacío, noten que los values son listas vacías

vocal_consonante = {'vocal':[], 'consonante':[]}

# %% [markdown]
# ## mini desafío 3
# En este mini desafío, usted y su equipo deben construir (en su casa) un diccionario en que las keys sean glottocodes de lenguas y los values sean glottocodes de familias lingüísticas.

# %%
## listas extraídas de glottolog! Las listas tienen la información ordenada de manera respectiva: la primera lengua en "lenguas"
## tiene por familia, el primer string de "familias", y así sucesivamente. 

lenguas = ['bora1263',
 'muin1242',
 'uruu1244',
 'chip1262',
 'umot1240',
 'otuk1240',
 'boro1282',
 'apur1254',
 'inap1243',
 'paca1247',
 'mach1268',
 'yine1238',
 'mash1270',
 'tere1279',
 'apol1242',
 'magi1242',
 'paun1241',
 'trin1274',
 'igna1246',
 'paic1240',
 'joaq1235',
 'baur1253',
 'noma1263',
 'caqu1242',
 'asha1243',
 'pich1237',
 'ajyi1238',
 'ucay1237',
 'ashe1272',
 'ashe1273',
 'sout3127',
 'mach1267',
 'nant1250',
 'guar1293',
 'yavi1244',
 'bani1254',
 'maip1246',
 'araw1276',
 'para1316',
 'wayu1243',
 'arai1239',
 'mara1409',
 'arua1264',
 'xiri1243',
 'uiri1238',
 'cari1280',
 'mana1299',
 'mapi1252',
 'mawa1268',
 'wapi1253',
 'ator1244',
 'kais1242',
 'resi1247',
 'pass1250',
 'juma1250',
 'cabi1241',
 'tari1256',
 'curr1243',
 'bani1255',
 'guar1294',
 'uain1239',
 'yucu1253',
 'acha1250',
 'piap1246',
 'mand1448',
 'ware1255',
 'guin1258',
 'anau1243',
 'yaba1249',
 'bare1276',
 'pali1279',
 'mara1408',
 'yane1238',
 'cham1318',
 'mori1273',
 'pare1272',
 'enaw1238',
 'sara1331',
 'yawa1261',
 'kust1238',
 'mehi1240',
 'waur1244',
 'maca1259',
 'guay1257',
 'cuib1242',
 'guah1255',
 'play1240',
 'agua1253',
 'shua1257',
 'achu1248',
 'huam1247',
 'kadi1248',
 'abip1241',
 'moco1246',
 'toba1269',
 'pila1245',
 'yagu1244',
 'peba1243',
 'yame1242',
 'cauq1239',
 'jaqa1244',
 'cent2142',
 'sout2996',
 'aura1243',
 'guaj1256',
 'xipa1240',
 'juru1256',
 'mari1442',
 'sanu1240',
 'nina1238',
 'yaro1235',
 'yano1262',
 'yano1261',
 'paum1247',
 'suru1263',
 'arua1263',
 'jama1261',
 'culi1244',
 'deni1241',
 'saba1268',
 'sout2994',
 'mama1278',
 'tawa1278',
 'lako1248',
 'latu1238',
 'kata1270',
 'kana1291',
 'mapu1245',
 'huil1244',
 'apal1257',
 'opon1234',
 'japr1238',
 'yukp1241',
 'pime1237',
 'kuik1246',
 'mati1253',
 'palm1241',
 'gali1262',
 'cari1279',
 'trio1238',
 'paux1235',
 'akur1238',
 'maqu1238',
 'wayu1242',
 'waya1269',
 'tive1236',
 'yaoa1239',
 'kaxu1237',
 'waiw1244',
 'hixk1239',
 'enap1235',
 'macu1259',
 'pemo1248',
 'akaw1239',
 'pata1262',
 'tama1338',
 'paux1236',
 'para1309',
 'sapa1254',
 'mapo1246',
 'yaba1248',
 'pemo1245',
 'chai1253',
 'cuma1240',
 'waim1253',
 'bona1255',
 'baka1277',
 'apia1247',
 'yaru1255',
 'para1310',
 'ikpe1245',
 'nape1237',
 'roco1235',
 'urup1245',
 'yaru1257',
 'wany1246',
 'wari1268',
 'orow1243',
 'tora1263',
 'iten1243',
 'kuyu1236',
 'chap1269',
 'kite1237',
 'mill1237',
 'alle1238',
 'cana1260',
 'awac1239',
 'toto1306',
 'guam1248',
 'colo1256',
 'chac1249',
 'maca1260',
 'niva1238',
 'wich1262',
 'wich1263',
 'wich1264',
 'iyoj1235',
 'iyow1239',
 'cacu1241',
 'nuka1242']

# %%
familias = ['bora1262',
 'bora1262',
 'uruc1242',
 'uruc1242',
 'boro1281',
 'boro1281',
 'boro1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'araw1281',
 'guah1252',
 'guah1252',
 'guah1252',
 'guah1252',
 'guah1252',
 'jiva1245',
 'jiva1245',
 'jiva1245',
 'jiva1245',
 'guai1249',
 'guai1249',
 'guai1249',
 'guai1249',
 'guai1249',
 'peba1241',
 'peba1241',
 'peba1241',
 'ayma1253',
 'ayma1253',
 'ayma1253',
 'ayma1253',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'chib1249',
 'huit1251',
 'huit1251',
 'huit1251',
 'huit1251',
 'huit1251',
 'huit1251',
 'huit1251',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'quec1387',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'pano1259',
 'ticu1244',
 'ticu1244',
 'cahu1265',
 'cahu1265',
 'choc1280',
 'choc1280',
 'choc1280',
 'choc1280',
 'choc1280',
 'choc1280',
 'choc1280',
 'choc1280',
 'choc1280',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'tupi1275',
 'yano1268',
 'yano1268',
 'yano1268',
 'yano1268',
 'yano1268',
 'araw1282',
 'araw1282',
 'araw1282',
 'araw1282',
 'araw1282',
 'araw1282',
 'namb1299',
 'namb1299',
 'namb1299',
 'namb1299',
 'namb1299',
 'namb1299',
 'katu1274',
 'katu1274',
 'arau1255',
 'arau1255',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'cari1283',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'chap1271',
 'huar1251',
 'huar1251',
 'barb1265',
 'barb1265',
 'barb1265',
 'barb1265',
 'barb1265',
 'barb1265',
 'mata1289',
 'mata1289',
 'mata1289',
 'mata1289',
 'mata1289',
 'mata1289',
 'mata1289',
 'kaku1242',
 'kaku1242']

# %% [markdown]
# ## mini desafío 4
# En este mini desafío, usted y su equipo deben construir (en su casa) una lista con las familias únicas de la lista **familias**. **Recomendación.** Puede servir pensar de la siguiente forma: si recorremos la lista **familias**, y agregamos una familia a **familias_unicas**, hay que evitar agregarla otra vez. Para hacer eso, pueden usar una condición de tipo **if** y el comando mágico **in** o **not in.**

# %%
## otra vez, listas vacías

familias_unicas = []

# %% [markdown]
# ## mini desafío 5
# En este mini desafío, usted y su equipo deben construir (en su casa) un diccionario cuyas keys sean la lista **familias_unicas**, y cuyos values sean listas con todas las lenguas de **lenguas** que pertenezcan a esa familia. **Recomendación.** Usen el diccionario del mini desafío 3.

# %%
## inicializamos el diccionario usando esta forma

familia_lista_lenguas = {familia:[] for familia in familias_unicas}
